# %%
import sys

print("stdout 1")
sys.stdout.flush()
print("stderr 1", file=sys.stderr)
sys.stdout.flush()
print("stdout 2")
sys.stdout.flush()
print("stderr 2", file=sys.stderr)
sys.stdout.flush()
# Should preserve chronological order

# %%
# !cat stdddd.ipynb | jq
