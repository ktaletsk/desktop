# %%
import kyle
# Out:
# l::l;:oxxxxdxxd:........':,..'...',co;.;:;c;.. ......',:cc:;..,';,':oloc,'',,,,,
# ,,;llc..,,,,:odoc;:c;...   ..:';',,,. .'l:',
# ol:cloooxkdllo;,'''......:;'',..,;'.:;';:c;:'.....',,,,'::;'';l:;;;,dc:::''''.';
# ,.'ll;...'',;;:loclc'...  ...'...'.. ..';cl;
# c;',c:,'ldl,,;'..'',,'.....',,,'''...,,';:...'..;,:o:,,',,'.:l;,;c;'lc,.,,,'.'';
# :,'':;,,.... ..:lc:,....'....... ........;d:
# l:;.;:c;llc;','...............'','.'';...,''....:clx:,;'.'',c;...,,',''.,:,..'''
# ,,',::,,'''...;oo:,........     .. ..... .:,
# c;cc;:clodddo:,'''..';;,,..  .....''......,,'..,;codc:c,',:;;;;.,:'.....,;,..'''
# '..',,;,''...',;;;,.',,'.....,;;,.....   ...
# :;;;coccclcclc;;,,',::;,.  .............'........:oc,.,,;cccoxxc,'.....';c;.....
# ..,;:cc:,....','...'''......;looc,,.  ..   .
# ;'.'cc,';:,.;::c,..  ....  ...  ..   ';......    .;''.',:lcooxxc........,,....':
# ccccll:,.....','............,codlcl;.     ..
# ;o;,llc,';;:;:l:,''     ..'',,. .....;;.....     ......:,..'lkx:..   ...,,.',:ll
# ...
