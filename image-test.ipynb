# %%
from IPython.display import Image

Image("https://i.kym-cdn.com/photos/images/newsfeed/002/707/766/630.png", embed=True)

# %%
! cat image-test.ipynb | jq '.cells[].source'
# Out:
# [
#   "from IPython.display import Image\n",
#   "\n",
#   "Image(\"https://i.kym-cdn.com/photos/images/newsfeed/002/707/766/630.png\", e
# mbed=True)"
# ]
# [
#   "! echo"
# ]
# []
